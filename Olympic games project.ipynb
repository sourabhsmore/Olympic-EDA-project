# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Sourabh\Desktop\olympic_games.csv")

# %%
print(df.head())
# Out:
#    year games_type host_country host_city  athletes  teams  competitions  \
# 0  2022     Winter        China   Beijing      2834     91           109
# 1  2022     Winter        China   Beijing      2834     91           109
# 2  2022     Winter        China   Beijing      2834     91           109
# 3  2022     Winter        China   Beijing      2834     91           109
# 4  2022     Winter        China   Beijing      2834     91           109
#
#      country  gold  silver  bronze
# 0  Australia     1       2       1
# 1    Austria     7       7       4
# 2    Belarus     0       2       0
# 3    Belgium     1       0       1
# 4     Canada     4       8      14

# %%
print(df.shape)
# Out:
# (264, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          264 non-null    int64
#  1   games_type    264 non-null    object
#  2   host_country  264 non-null    object
#  3   host_city     264 non-null    object
#  4   athletes      264 non-null    int64
#  5   teams         264 non-null    int64
#  6   competitions  264 non-null    int64
#  7   country       264 non-null    object
#  8   gold          264 non-null    int64
#  9   silver        264 non-null    int64
#  10  bronze        264 non-null    int64
# dtypes: int64(7), object(4)
# memory usage: 22.8+ KB

# %%
df.describe()
# Out:
#               year      athletes       teams  competitions        gold  \
# count   264.000000    264.000000  264.000000    264.000000  264.000000
# mean   2018.098485   8590.848485  169.117424    252.318182    3.621212
# std       2.461444   3986.963484   54.332778    103.902983    6.127331
# min    2014.000000   2780.000000   88.000000     98.000000    0.000000
# 25%    2016.000000   2834.000000   92.000000    109.000000    0.000000
# 50%    2018.000000  11238.000000  206.000000    306.000000    1.000000
# 75%    2020.000000  11420.000000  207.000000    339.000000    4.000000
# max    2022.000000  11420.000000  207.000000    339.000000   46.000000
#
#            silver      bronze
# count  264.000000  264.000000
# mean     3.609848    4.060606
# std      5.455947    5.519075
# min      0.000000    0.000000
# 25%      0.000000    1.000000
# 50%      2.000000    2.000000
# 75%      5.000000    5.000000
# max     41.000000   38.000000

# %%
df.columns.tolist()
# Out:
# ['year',
#  'games_type',
#  'host_country',
#  'host_city',
#  'athletes',
#  'teams',
#  'competitions',
#  'country',
#  'gold',
#  'silver',
#  'bronze']

# %%
df.isnull().sum()
# Out:
# year            0
# games_type      0
# host_country    0
# host_city       0
# athletes        0
# teams           0
# competitions    0
# country         0
# gold            0
# silver          0
# bronze          0
# dtype: int64

# %%
df.nunique()
# Out:
# year              5
# games_type        2
# host_country      5
# host_city         5
# athletes          5
# teams             5
# competitions      5
# country         105
# gold             24
# silver           22
# bronze           26
# dtype: int64

# %%
print(df.tail())
# Out:
#      year games_type        host_country host_city  athletes  teams  \
# 259  2014     Winter  Russian Federation     Sochi      2780     88
# 260  2014     Winter  Russian Federation     Sochi      2780     88
# 261  2014     Winter  Russian Federation     Sochi      2780     88
# 262  2014     Winter  Russian Federation     Sochi      2780     88
# 263  2014     Winter  Russian Federation     Sochi      2780     88
#
#      competitions                   country  gold  silver  bronze
# 259            98                    Sweden     2       7       6
# 260            98               Switzerland     7       2       2
# 261            98                   Ukraine     1       0       1
# 262            98            United Kingdom     1       1       3
# 263            98  United States of America     9       9      10

# %%
df
# Out:
#      year games_type        host_country host_city  athletes  teams  \
# 0    2022     Winter               China   Beijing      2834     91
# 1    2022     Winter               China   Beijing      2834     91
# 2    2022     Winter               China   Beijing      2834     91
# 3    2022     Winter               China   Beijing      2834     91
# 4    2022     Winter               China   Beijing      2834     91
# ..    ...        ...                 ...       ...       ...    ...
# 259  2014     Winter  Russian Federation     Sochi      2780     88
# 260  2014     Winter  Russian Federation     Sochi      2780     88
# 261  2014     Winter  Russian Federation     Sochi      2780     88
# 262  2014     Winter  Russian Federation     Sochi      2780     88
# 263  2014     Winter  Russian Federation     Sochi      2780     88
#
#      competitions                   country  gold  silver  bronze
# 0             109                 Australia     1       2       1
# ...

# %%
o = df.groupby('host_city')['host_city'].count()

# %%
sns.barplot(x=o.index , y=o.values)
# Out:
# <Axes: xlabel='host_city'>

# %%
o = df.groupby('year')['year'].count()

# %%
sns.barplot(x=o.index , y=o.values)
# Out:
# <Axes: xlabel='year'>

# %%
sns.swarmplot(df.sample(200).year)
# Out:
# <Axes: ylabel='year'>

# %%
sns.lineplot(data = df, x='year', y='games_type')
# Out:
# <Axes: xlabel='year', ylabel='games_type'>

# %%
sns.swarmplot(x='silver' , y='year' ,data=df)
# Out:
# <Axes: xlabel='silver', ylabel='year'>

# %%
x = np.random.normal(size = 1000)

# %%
sns.distplot(df.teams)
# Out:
# <Axes: xlabel='teams', ylabel='Density'>

# %%
sns.distplot(df.gold, kde=False)
# Out:
# <Axes: xlabel='gold'>

# %%
sns.kdeplot(df.gold , color='Green')
sns.kdeplot(df.silver, color='Red')
sns.kdeplot(df.bronze, color='Blue')
# Out:
# <Axes: xlabel='gold', ylabel='Density'>

# %%
x = np.random.normal(size=1000)
y = np.random.normal(size=1000)

# %%
sns.pairplot(df)

# %%
sns.violinplot(x='athletes', data=df)
# Out:
# <Axes: xlabel='athletes'>

# %%
sns.violinplot(x='year', data=df)
# Out:
# <Axes: xlabel='year'>

# %%
sns.violinplot(x='year', y='gold', data=df)
# Out:
# <Axes: xlabel='year', ylabel='gold'>

# %%
sns.swarmplot(x='host_country', y='gold', hue='year', data=df)
# Out:
# <Axes: xlabel='host_country', ylabel='gold'>

# %%
sns.violinplot(x='host_country', y='gold', hue='games_type', split=False, data=df)
# Out:
# <Axes: xlabel='host_country', ylabel='gold'>

# %%
o = df.groupby('host_country')['host_country'].count()

# %%
plt.pie(o)
plt.show()

# %%
plt.pie(o, labels=o.index)
plt.title('Olympic games host by countries')
plt.show()

# %%
plt.pie(o, labels = o.index, autopct = "%.2f%%")
plt.title('Most participants athletes by countries: ')
plt.show()

# %%
plt.pie(o, labels = o.index, autopct = "%.2f%%", wedgeprops = dict(width = 0.3))
plt.title('Donut chart')
plt.show()

# %%
sns.scatterplot(x='country',y='silver', data=df)
# Out:
# <Axes: xlabel='country', ylabel='silver'>

# %%
sns.scatterplot(x='country',y='silver',hue='games_type',data=df)
# Out:
# <Axes: xlabel='country', ylabel='silver'>

# %%
sns.lineplot(x=df.bronze , y=df.host_country)
# Out:
# <Axes: xlabel='bronze', ylabel='host_country'>

# %%
sns.lineplot(x='bronze', y='country', hue='host_country', data=df)
# Out:
# <Axes: xlabel='bronze', ylabel='country'>

# %%
x  = np.random.rand(10,10)

# %%
x
# Out:
# array([[0.32949748, 0.07650428, 0.89533975, 0.12889667, 0.95193935,
#         0.73602296, 0.14193666, 0.18938673, 0.57785307, 0.2828469 ],
#        [0.13611271, 0.86875403, 0.14222995, 0.0918157 , 0.23791137,
#         0.34798433, 0.37349766, 0.8218226 , 0.04177999, 0.6967622 ],
#        [0.76874623, 0.70746046, 0.46910614, 0.10358669, 0.42778156,
#         0.33144385, 0.03990251, 0.3875119 , 0.27810008, 0.43277541],
#        [0.44236645, 0.51610692, 0.51849384, 0.16374703, 0.54484976,
#         0.94845468, 0.77316931, 0.54565828, 0.27369883, 0.83460333],
#        [0.30378665, 0.0841241 , 0.98083324, 0.09924418, 0.24721674,
#         0.8855827 , 0.6485627 , 0.414426  , 0.04402926, 0.61275392],
#        [0.238086  , 0.4170624 , 0.32949862, 0.5270693 , 0.61377169,
#         0.05108452, 0.79925545, 0.20809059, 0.27351376, 0.12163346],
#        [0.94048042, 0.7005693 , 0.92895606, 0.32653331, 0.98230857,
#         0.40924521, 0.47271056, 0.30381065, 0.65754171, 0.83256611],
# ...

# %%
sns.heatmap(x)
# Out:
# <Axes: >

# %%
df['games_type'].value_counts()
# Out:
# games_type
# Summer    179
# Winter     85
# Name: count, dtype: int64

# %%
sns.heatmap(x, annot=True)
# Out:
# <Axes: >
